// %%
scala.util.Properties.versionString
// Out:
// res1: String = "version 2.12.21"

// %%
scala.util.Properties.versionString
// Out:
// res2: String = "version 2.12.21"

// %%
val nombre: String = "Eric"
val partidas: Int = 5
val puntuacion: Int = 11
val tasaVictorias: Double = 67
val jugadorActivo: Boolean = true


val nombre = "Eric"
val partidas = 5
val puntuacion = 11
val tasaVictorias = 67
val jugadorActivo = true
// Out:
// cmd3.sc:8: nombre is already defined as value nombre
// val nombre = "Eric"
//     ^
// cmd3.sc:9: partidas is already defined as value partidas
// val partidas = 5
//     ^
// cmd3.sc:10: puntuacion is already defined as value puntuacion
// val puntuacion = 11
//     ^
// cmd3.sc:11: tasaVictorias is already defined as value tasaVictorias
// val tasaVictorias = 67
//     ^
// cmd3.sc:12: jugadorActivo is already defined as value jugadorActivo
// val jugadorActivo = true
//     ^
// Compilation Failed

// %%
val nombre: String = "Eric"
val partidas: Int = 5
val puntuacion: Int = 11
val tasaVictorias: Double = 67
val jugadorActivo: Boolean = true
// Out:
// nombre: String = "Eric"
// partidas: Int = 5
// puntuacion: Int = 11
// tasaVictorias: Double = 67.0
// jugadorActivo: Boolean = true

// %%
val nombre = "Eric"
val partidas = 5
val puntuacion = 11
val tasaVictorias = 67
val jugadorActivo = true
// Out:
// nombre: String = "Eric"
// partidas: Int = 5
// puntuacion: Int = 11
// tasaVictorias: Int = 67
// jugadorActivo: Boolean = true

// %%
val jugador = "Marta"
var puntuacion = 10
// Out:
// jugador: String = "Marta"
// puntuacion: Int = 10

// %%
val jugador = "Marta"
var puntuacion = 10
var puntuacion = 15
// Out:
// cmd6.sc:6: puntuacion$value is already defined as value puntuacion$value
// val puntuacion$value = new _root_.almond.api.internal.Modifiable(15
//     ^
// Compilation Failed

// %%
val jugador = "Marta"
var puntuacion = 10
puntuacion = puntuacion + 5
println(puntuacion)
// Out:
// 15
// jugador: String = "Marta"
// puntuacion: Int = 15

// %%
val jugador = "Marta"
var puntuacion = 15
puntuacion = puntuacion + 3
println(puntuacion)
// Out:
// 18
// jugador: String = "Marta"
// puntuacion: Int = 18

// %%
val jugador = "Marta"
var puntuacion = 10
puntuacion = puntuacion + 5
puntuacion = puntuacion + 3
println(puntuacion)
// Out:
// 18
// jugador: String = "Marta"
// puntuacion: Int = 18

// %%
val jugador = "Marta"
jugador = "Eric"
// Out:
// cmd9.sc:2: reassignment to val
// val res9_1 = jugador = "Eric"
//                      ^
// Compilation Failed

// %%
var jugador = "Marta"
jugador = "Eric"
// Out:
// jugador: String = "Eric"

// %%
val numeroPi: Double = 3.14159265358979323846264338327
val numeroPi: Float = 3.14159265358979323846264338327
// Out:
// cmd10.sc:2: numeroPi is already defined as value numeroPi
// val numeroPi: Float = 3.14159265358979323846264338327
//     ^
// cmd10.sc:2: type mismatch;
//  found   : Double(3.141592653589793)
//  required: Float
// val numeroPi: Float = 3.14159265358979323846264338327
//                       ^
// Compilation Failed

// %%
val numeroPi: Double = 3.14159265358979323846264338327
// Out:
// numeroPi: Double = 3.141592653589793

// %%
val numeroPi: Float = 3.14159265358979323846264338327f
// Out:
// numeroPi: Float = 3.1415927F

// %%
val estudiantes: Int = 25
val aprobado: Boolean = true
val curso: String = "Big Data"
// Out:
// estudiantes: Int = 25
// aprobado: Boolean = true
// curso: String = "Big Data"

// %%
var hand1 = 18
var hand2 = 21
var hand3 = 22
var hand4 = 30



def bust(hand: Int):Boolean =
if (hand > 21) {
true
}else{
false
}
bust(hand1)
bust(hand2)
bust(hand3)
bust(hand4)
// Out:
// hand1: Int = 18
// hand2: Int = 21
// hand3: Int = 22
// hand4: Int = 30
// defined function bust
// res14_5: Boolean = false
// res14_6: Boolean = false
// res14_7: Boolean = true
// res14_8: Boolean = true

// %%
def maxHand(valor1: Int, valor2: Int): Int = {
  if (valor1 > valor2) {
    valor1
  } else {
    valor2
  }
}
maxHand(17, 19)
maxHand(20, 18)
maxHand(21, 21)
maxHand(30,30)
// Out:
// defined function maxHand
// res16_1: Int = 19
// res16_2: Int = 20
// res16_3: Int = 21
// res16_4: Int = 30

// %%
def bust(hand: Int):Boolean =
if (hand > 21) {
true
}else{
false
}
def maxHand(valor1: Int, valor2: Int): Int = {
  if (valor1 > valor2) {
    valor1
  } else {
    valor2
  }
}
def ganador(handA: Int, handB: Int): Int = {
    if(bust(handA) && bust(handB)){
        0
    }
    else if (bust(handA)){
        handB
    }
    else if (bust(handB)){
        handA
    }
    else {
        maxHand(handA,handB)
        
    }
    
}

ganador(26, 20) 
ganador(18, 22) 
ganador(24, 25) 
ganador(17, 19) 
ganador(21, 20)
// Out:
// defined function bust
// defined function maxHand
// defined function ganador
// res17_3: Int = 20
// res17_4: Int = 18
// res17_5: Int = 0
// res17_6: Int = 19
// res17_7: Int = 21

// %%
val jugadores = Array("Alex", "Chen", "Marta")
println(jugadores)
jugadores(0) = "Sindhu"
println(jugadores)
// Out:
// [Ljava.lang.String;@73aa88b5
// [Ljava.lang.String;@73aa88b5
// jugadores: Array[String] = Array("Sindhu", "Chen", "Marta")

// %%
val jugadores = Array("Alex", "Chen", "Marta")
println(jugadores)
jugadores(0) = "Sindhu"
println(jugadores)
jugadores(0) = 500
println(jugadores)
// Out:
// cmd20.sc:5: type mismatch;
//  found   : Int(500)
//  required: String
// val res20_4 = jugadores(0) = 500
//                              ^
// Compilation Failed

// %%
val Array =new Array[Int](4)
Array(0)= 17
Array(1)= 24
Array(2)= 21
Array(3)= 19
println(Array.length)
// Out:
// 4
// Array: Array[Int] = Array(17, 24, 21, 19)

// %%
def bust(hand: Int):Boolean =
if (hand > 21) {
true
}else{
false
}


val manos = Array(17, 24, 21, 19, 26)
var i = 0
while (i < manos.length) {
  val manoActual = manos(i)
  val sePasa = bust(manoActual)
  println(s"Mano: $manoActual - ¿Se pasa de 21?: $sePasa")
  i += 1
}
// Out:
// cmd25.sc:9: 4 more arguments than can be applied to method apply: (i: Int)Int in class Array
// val manos = Array(17, 24, 21, 19, 26)
//                       ^
// Compilation Failed

// %%
def bust(hand: Int):Boolean =
if (hand > 21) {
true
}else{
false
}


val manos = scala.Array(17, 24, 21, 19, 26)
var i = 0
while (i < manos.length) {
  val manoActual = manos(i)
  val sePasa = bust(manoActual)
  println(s"Mano: $manoActual - ¿Se pasa de 21?: $sePasa")
  i += 1
}
// Out:
// Mano: 17 - ¿Se pasa de 21?: false
// Mano: 24 - ¿Se pasa de 21?: true
// Mano: 21 - ¿Se pasa de 21?: false
// Mano: 19 - ¿Se pasa de 21?: false
// Mano: 26 - ¿Se pasa de 21?: true
// defined function bust
// manos: Array[Int] = Array(17, 24, 21, 19, 26)
// i: Int = 5

// %%
val jugadores = List("Alex", "Chen", "Marta")
println (jugadores)
// Out:
// List(Alex, Chen, Marta)
// jugadores: List[String] = List("Alex", "Chen", "Marta")

// %%
val jugadores = List("Alex", "Chen", "Marta")
println (jugadores)
val jugadoresNuevos = ("Sindhu" :: jugadores)
println (jugadoresNuevos)
println (jugadores)
// Out:
// List(Alex, Chen, Marta)
// List(Sindhu, Alex, Chen, Marta)
// List(Alex, Chen, Marta)
// jugadores: List[String] = List("Alex", "Chen", "Marta")
// jugadoresNuevos: List[String] = List("Sindhu", "Alex", "Chen", "Marta")

// %%
val jugadores = List("Alex", "Chen", "Marta")
println (jugadores)
val jugadoresNuevos = ("Sindhu" :: jugadores)
println (jugadoresNuevos)
println (jugadores)
println (jugadoresNuevos.length)
println (jugadores.length)
println (jugadoresNuevos.reverse)
// Out:
// List(Alex, Chen, Marta)
// List(Sindhu, Alex, Chen, Marta)
// List(Alex, Chen, Marta)
// 4
// 3
// List(Marta, Chen, Alex, Sindhu)
// jugadores: List[String] = List("Alex", "Chen", "Marta")
// jugadoresNuevos: List[String] = List("Sindhu", "Alex", "Chen", "Marta")

// %%
val listaNil = "Ana" :: "Luis" :: "Marta" :: Nil
println(listaNil)

val listaNil2 = "Pedro" :: "Sofia" :: Nil

val listaFinal = listaNil ::: listaNil2

println(listaFinal)
println(listaNil)
println(listaNil2)
// Out:
// List(Ana, Luis, Marta)
// List(Ana, Luis, Marta, Pedro, Sofia)
// List(Ana, Luis, Marta)
// List(Pedro, Sofia)
// listaNil: List[String] = List("Ana", "Luis", "Marta")
// listaNil2: List[String] = List("Pedro", "Sofia")
// listaFinal: List[String] = List("Ana", "Luis", "Marta", "Pedro", "Sofia")

// %%
val handA = 18
val handB = 21
val handC = 25


val esMayor = handA > handB
val esIgual = handB == 21
val esDistinto = handC != 21


val ambasValidas = (handA <= 21) && (handB <= 21)
val algunaSePasa = (handA > 21) || (handC > 21)
val bNoEs21 = !(handB == 21)

println(s"handA > handB: $esMayor")
println(s"handB == 21: $esIgual")
println(s"handC != 21: $esDistinto")
println(s"handA <= 21 && handB <= 21: $ambasValidas")
println(s"handA > 21 || handC > 21: $algunaSePasa")
println(s"!(handB == 21): $bNoEs21")
// Out:
// handA > handB: false
// handB == 21: true
// handC != 21: true
// handA <= 21 && handB <= 21: true
// handA > 21 || handC > 21: true
// !(handB == 21): false
// handA: Int = 18
// handB: Int = 21
// handC: Int = 25
// esMayor: Boolean = false
// esIgual: Boolean = true
// esDistinto: Boolean = true
// ambasValidas: Boolean = true
// algunaSePasa: Boolean = true
// bNoEs21: Boolean = false

// %%
def bust(hand: Int):Boolean =
if (hand > 21) {
true
}else{
false
}

val manos = scala.Array(17, 24, 21, 26, 18)

var i = 0
while (i < manos.length) {
  val manoActual = manos(i)
  val sePasa = bust(manoActual)
  println(s"Mano: $manoActual - ¿Se pasa de 21?: $sePasa")
  i += 1
}

manos.foreach { mano =>
  if (mano > 21) {
    println(s"$mano se pasa")
  } else {
    println(s"$mano es valida")
  }
}
// Out:
// Mano: 17 - ¿Se pasa de 21?: false
// Mano: 24 - ¿Se pasa de 21?: true
// Mano: 21 - ¿Se pasa de 21?: false
// Mano: 26 - ¿Se pasa de 21?: true
// Mano: 18 - ¿Se pasa de 21?: false
// 17 es valida
// 24 se pasa
// 21 es valida
// 26 se pasa
// 18 es valida
// defined function bust
// manos: Array[Int] = Array(17, 24, 21, 26, 18)
// i: Int = 5

// %%
var total = 0

def sumarAlTotal(valor: Int) = {
  total = total + valor
}
println(sumarAlTotal(total))
println(sumarAlTotal(total))
println(sumarAlTotal(total))
println(sumarAlTotal(total))
println(sumarAlTotal(total))
println(sumarAlTotal(total))
println(sumarAlTotal(total))
// Out:
// ()
// ()
// ()
// ()
// ()
// ()
// ()
// total: Int = 0
// defined function sumarAlTotal

// %%
var total = 0

def sumarAlTotal(valor: Int): Unit = {
  total = total + valor
}

sumarAlTotal(5)
println(s"Total tras sumar 5: $total")

sumarAlTotal(10)
println(s"Total tras sumar 10: $total")

sumarAlTotal(20)
println(s"Total tras sumar 20: $total")


def sumar(a: Int, b: Int): Int = {
  a + b
}

val resultado1 = sumar(10, 5)
println(s"Resultado función pura sumar(10, 5): $resultado1")

val resultado2 = sumar(resultado1, 20)
println(s"Resultado función pura sumar($resultado1, 20): $resultado2")
// Out:
// Total tras sumar 5: 5
// Total tras sumar 10: 15
// Total tras sumar 20: 35
// Resultado función pura sumar(10, 5): 15
// Resultado función pura sumar(15, 20): 35
// total: Int = 35
// defined function sumarAlTotal
// defined function sumar
// resultado1: Int = 15
// resultado2: Int = 35

// %%
def bust(hand: Int): Boolean = {
  if (hand > 21) true else false
}

def maxHand(valor1: Int, valor2: Int): Int = {
  if (valor1 > valor2) valor1 else valor2
}

val jugadores = List("Alex", "Chen", "Marta", "Sindhu")
val manos = scala.Array(18, 24, 21, 20)
val manosRonda2 = scala.Array(22, 19, 20, 21)

println("--- RONDA 1 ---")
var i = 0
var mejorPuntuacionR1 = 0

while (i < manos.length) {
  val jugador = jugadores(i)
  val puntuacion = manos(i)
  val sePasa = bust(puntuacion)

  if (sePasa) {
    println(s"$jugador sacó $puntuacion: ¡Se pasa de 21! (Eliminado)")
  } else {
    println(s"$jugador sacó $puntuacion: Puntuación válida")
    mejorPuntuacionR1 = maxHand(mejorPuntuacionR1, puntuacion)
  }
  i += 1
}
println(s"Mejor puntuación válida Ronda 1: $mejorPuntuacionR1\n")

println(" RONDA 2 ")
var mejorPuntuacionR2 = 0

manosRonda2.foreach { puntuacion =>
  if (!bust(puntuacion)) {
    println(s"Puntuación válida en Ronda 2: $puntuacion")
    mejorPuntuacionR2 = maxHand(mejorPuntuacionR2, puntuacion)
  } else {
    println(s"Puntuación $puntuacion: ¡Se pasa de 21!")
  }
}
println(s"Mejor puntuación válida Ronda 2: $mejorPuntuacionR2")
// Out:
// --- RONDA 1 ---
// Alex sacó 18: Puntuación válida
// Chen sacó 24: ¡Se pasa de 21! (Eliminado)
// Marta sacó 21: Puntuación válida
// Sindhu sacó 20: Puntuación válida
// Mejor puntuación válida Ronda 1: 21
//
//  RONDA 2
// Puntuación 22: ¡Se pasa de 21!
// Puntuación válida en Ronda 2: 19
// Puntuación válida en Ronda 2: 20
// Puntuación válida en Ronda 2: 21
// Mejor puntuación válida Ronda 2: 21
// defined function bust
// defined function maxHand
// jugadores: List[String] = List("Alex", "Chen", "Marta", "Sindhu")
// manos: Array[Int] = Array(18, 24, 21, 20)
// manosRonda2: Array[Int] = Array(22, 19, 20, 21)
// i: Int = 4
// mejorPuntuacionR1: Int = 21
// mejorPuntuacionR2: Int = 21
